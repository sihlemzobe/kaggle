# %%
import pandas as pd

# %%
df_holid = pd.read_csv(r"C:\Users\sihle\Downloads\store-sales-time-series-forecasting\holidays_events.csv")
df_oil = pd.read_csv(r"C:\Users\sihle\Downloads\store-sales-time-series-forecasting\oil.csv")
df_samp = pd.read_csv(r"C:\Users\sihle\Downloads\store-sales-time-series-forecasting\sample_submission.csv")
df_stores = pd.read_csv(r"C:\Users\sihle\Downloads\store-sales-time-series-forecasting\stores.csv")
df_test = pd.read_csv(r"C:\Users\sihle\Downloads\store-sales-time-series-forecasting\test.csv")
df_train = pd.read_csv(r"C:\Users\sihle\Downloads\store-sales-time-series-forecasting\train.csv")
df_trans = pd.read_csv(r"C:\Users\sihle\Downloads\store-sales-time-series-forecasting\transactions.csv")

# %% [markdown]
# # explore each dataframe

# %%
df_holid.head()
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
trans_holid = df_holid[df_holid['transferred'] != False].value_counts()

print(f'number of transfarred holidays {trans_holid.sum()}')
trans_holid
# Out:
# number of transfarred holidays 12
# date        type     locale    locale_name  description                    transferred
# 2017-12-06  Holiday  Local     Quito        Fundacion de Quito             True           1
# 2017-09-28  Holiday  Local     Ibarra       Fundacion de Ibarra            True           1
# 2017-08-10  Holiday  National  Ecuador      Primer Grito de Independencia  True           1
# 2017-05-24  Holiday  National  Ecuador      Batalla de Pichincha           True           1
# 2017-04-12  Holiday  Local     Cuenca       Fundacion de Cuenca            True           1
# 2017-01-01  Holiday  National  Ecuador      Primer dia del ano             True           1
# 2016-08-10  Holiday  National  Ecuador      Primer Grito de Independencia  True           1
# 2016-07-25  Holiday  Local     Guayaquil    Fundacion de Guayaquil         True           1
# 2016-05-24  Holiday  National  Ecuador      Batalla de Pichincha           True           1
# ...

# %% [markdown]
# 12 holidays were transfarred.6 of them were in 2017 and 4 in 2016

# %%
df_holid.dtypes
# Out:
# date           object
# type           object
# locale         object
# locale_name    object
# description    object
# transferred      bool
# dtype: object

# %% [markdown]
# change date column to datetime dtype

# %%
df_holid['date'] = pd.to_datetime(df_holid['date'])

# %%
df_holid.dtypes
# Out:
# date           datetime64[ns]
# type                   object
# locale                 object
# locale_name            object
# description            object
# transferred              bool
# dtype: object

# %% [markdown]
# save date column as an index (much more convenient to index rows by dates)

# %%
df_holid = df_holid.set_index('date')

# %%
df_holid.head()
# Out:
#                type    locale locale_name                    description  \
# date
# 2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#             transferred
# date
# 2012-03-02        False
# 2012-04-01        False
# 2012-04-12        False
# 2012-04-14        False
# 2012-04-21        False

# %%
df_oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %% [markdown]
# how many NaN values in dcoilwtico?

# %%
df_oil['dcoilwtico'].isnull().sum()
# Out:
# 43

# %% [markdown]
# drop null values

# %%
df_oil.dropna(inplace=True)

# %%
df_oil.head()
# Out:
#          date  dcoilwtico
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20
# 5  2013-01-08       93.21

# %%
df_samp.head()
# Out:
#         id  sales
# 0  3000888    0.0
# 1  3000889    0.0
# 2  3000890    0.0
# 3  3000891    0.0
# 4  3000892    0.0

# %% [markdown]
# no sales made

# %%
df_stores.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
df_stores.shape
# Out:
# (54, 5)

# %% [markdown]
# we are looking at 54 diffrent stores

# %%
df_test.head()
# Out:
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
df_test.shape

# %%
df_test['family'].unique()
# Out:
# array(['AUTOMOTIVE', 'BABY CARE', 'BEAUTY', 'BEVERAGES', 'BOOKS',
#        'BREAD/BAKERY', 'CELEBRATION', 'CLEANING', 'DAIRY', 'DELI', 'EGGS',
#        'FROZEN FOODS', 'GROCERY I', 'GROCERY II', 'HARDWARE',
#        'HOME AND KITCHEN I', 'HOME AND KITCHEN II', 'HOME APPLIANCES',
#        'HOME CARE', 'LADIESWEAR', 'LAWN AND GARDEN', 'LINGERIE',
#        'LIQUOR,WINE,BEER', 'MAGAZINES', 'MEATS', 'PERSONAL CARE',
#        'PET SUPPLIES', 'PLAYERS AND ELECTRONICS', 'POULTRY',
#        'PREPARED FOODS', 'PRODUCE', 'SCHOOL AND OFFICE SUPPLIES',
#        'SEAFOOD'], dtype=object)

# %%
df_test['family'].nunique()
# Out:
# 33

# %% [markdown]
# the store have 33 different product departments
#
# but which products are always on promotion?

# %%
df_test[df_test['onpromotion'] > 70].head(50)
# Out:
#           id        date  store_nbr     family  onpromotion
# 30   3000918  2017-08-16          1    PRODUCE          256
# 41   3000929  2017-08-16         10      DAIRY          106
# 45   3000933  2017-08-16         10  GROCERY I           96
# 63   3000951  2017-08-16         10    PRODUCE          230
# 74   3000962  2017-08-16         11      DAIRY          145
# 78   3000966  2017-08-16         11  GROCERY I          102
# 96   3000984  2017-08-16         11    PRODUCE          163
# 107  3000995  2017-08-16         12      DAIRY          115
# 111  3000999  2017-08-16         12  GROCERY I           87
# 129  3001017  2017-08-16         12    PRODUCE          219
# 140  3001028  2017-08-16         13      DAIRY          107
# 144  3001032  2017-08-16         13  GROCERY I           90
# 162  3001050  2017-08-16         13    PRODUCE          244
# 173  3001061  2017-08-16         14      DAIRY          114
# 177  3001065  2017-08-16         14  GROCERY I           88
# ...

# %%
df_test['onpromotion'].describe()
# Out:
# count    28512.000000
# mean         6.965383
# std         20.683952
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          6.000000
# max        646.000000
# Name: onpromotion, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.hist(
    [df_test['family'],df_test['onpromotion'].count()], 
    alpha = 0.7,
    color = ['red', 'blue'],
    label = ['Pittsburgh', 'Las Vegas'],
    bins = 'auto'
   )

plt.xlabel('Rating')
plt.ylabel('Number of Rating Scores')

plt.legend(loc = 'best')

plt.title('Review distribution of Pittsburgh and Las Vegas')

plt.show()

# %%
df_test[['onpromotion','family']].head()
# Out:
#    onpromotion      family
# 0            0  AUTOMOTIVE
# 1            0   BABY CARE
# 2            2      BEAUTY
# 3           20   BEVERAGES
# 4            0       BOOKS
